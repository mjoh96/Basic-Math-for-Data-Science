# %% [markdown]
# # 가장 큰 글씨
# ## 좀더 작은 글씨

# %%
# Ex 1-14
import numpy as np
import matplotlib.pyplot as plt
# (a) f(x)=3x-4
def f(x):
    return 3*x - 4
# f^-1(x) = (x + 4)/3
def f_inv(x):
    return (x+4)/3
#y=x
def identity(x):
    return x

#f=f^-1
x=np.linspace(-1,5,601)
graph, = plt.plot(x,(f(x)))
graph1, = plt.plot(x,f_inv(x))
graph2, = plt.plot(x,identity(x),'--')

plt.legend(handles=(graph,graph1,graph2),
           labels=(r'$y=f(x)$',r'$y=f^{-1}(x)$',r'$y=x$'))
plt.ylim(-1,5)
plt.show()

# (b) g(x)=x^2+1
def g(x):
    return x**2+1

# g^-1(x)=sqrt(x-1)
def g_inv(x):
    return np.sqrt(x-1)

#g=g^-1
x=np.linspace(0,6,601)
graph, = plt.plot(x,g(x))
graph1, = plt.plot(x,g_inv(x))
graph2, = plt.plot(x,identity(x),'--')
plt.legend(handles=(graph,graph1,graph2),
labels=(r'$y=g(x)$',r'$y=g^{-1}(x)$',r'$y=x$'))
plt.ylim(0,6)
plt.show()
# Out:
# /var/folders/q1/zrny0q510xb941tzkhp44nqc0000gn/T/ipykernel_1344/2579443725.py:31: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(x-1)
